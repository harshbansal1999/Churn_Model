# %% [markdown]
# # INSAID Hiring Exercise

# %% [markdown]
# ## Important: Kindly go through the instructions mentioned below.
#
# - The Sheet is structured in **4 steps**:
#     1. Understanding data and manipulation
#     2. Data visualization
#     3. Implementing Machine Learning models(Note: It should be more than 1 algorithm)
#     4. Model Evaluation and concluding with the best of the model.
#
#
#
#
# - Try to break the codes in the **simplest form** and use number of code block with **proper comments** to them
# - We are providing **h** different dataset to choose from(Note: You need to select any one of the dataset from this sample sheet only)
# - The **interview calls** will be made solely based on how good you apply the **concepts**.
# - Good Luck! Happy Coding!

# %% [markdown]
# ### Importing the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Churn.csv")

# %% [markdown]
# ### Understanding the data

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
#No. of Features = 21

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#Object Features will be converted into numerical for analysis using label endcoder

# %% [markdown]
# ### Data Manipulation

# %%
data.customerID=data.customerID.str[:4]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder1=LabelEncoder()
data["gender"]=label_encoder1.fit_transform(data["gender"])
label_encoder2=LabelEncoder()
data["Partner"]=label_encoder2.fit_transform(data["Partner"])
label_encoder3=LabelEncoder()
data["Dependents"]=label_encoder3.fit_transform(data["Dependents"])
label_encoder4=LabelEncoder()
data["PhoneService"]=label_encoder4.fit_transform(data["PhoneService"])
label_encoder5=LabelEncoder()
data["MultipleLines"]=label_encoder5.fit_transform(data["MultipleLines"])
label_encoder6=LabelEncoder()
data["InternetService"]=label_encoder6.fit_transform(data["InternetService"])
label_encoder7=LabelEncoder()
data["OnlineSecurity"]=label_encoder7.fit_transform(data["OnlineSecurity"])
label_encoder8=LabelEncoder()
data["OnlineBackup"]=label_encoder8.fit_transform(data["OnlineBackup"])
label_encoder9=LabelEncoder()
data["DeviceProtection"]=label_encoder9.fit_transform(data["DeviceProtection"])
label_encoder10=LabelEncoder()
data["TechSupport"]=label_encoder10.fit_transform(data["TechSupport"])
label_encoder11=LabelEncoder()
data["StreamingTV"]=label_encoder11.fit_transform(data["StreamingTV"])
label_encoder12=LabelEncoder()
data["StreamingMovies"]=label_encoder12.fit_transform(data["StreamingMovies"])
label_encoder13=LabelEncoder()
data["Contract"]=label_encoder13.fit_transform(data["Contract"])
label_encoder14=LabelEncoder()
data["PaperlessBilling"]=label_encoder14.fit_transform(data["PaperlessBilling"])
label_encoder15=LabelEncoder()
data["PaymentMethod"]=label_encoder15.fit_transform(data["PaymentMethod"])
label_encoder16=LabelEncoder()
data["TotalCharges"]=label_encoder16.fit_transform(data["TotalCharges"])
label_encoder17=LabelEncoder()
data["Churn"]=label_encoder17.fit_transform(data["Churn"])

# %%
data["customerID"]=data.customerID.astype(int)

# %%
data.corr()
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006073      -0.002197 -0.026779   -0.012816
# gender              0.006073  1.000000      -0.001874 -0.001808    0.010517
# SeniorCitizen      -0.002197 -0.001874       1.000000  0.016479   -0.211185
# Partner            -0.026779 -0.001808       0.016479  1.000000    0.452676
# Dependents         -0.012816  0.010517      -0.211185  0.452676    1.000000
# tenure              0.007805  0.005106       0.016567  0.379697    0.159712
# PhoneService       -0.006252 -0.006488       0.008576  0.017706   -0.001762
# MultipleLines       0.004366 -0.006739       0.146185  0.142410   -0.024991
# InternetService    -0.012230 -0.000863      -0.032310  0.000891    0.044590
# OnlineSecurity      0.013174 -0.015017      -0.128221  0.150828    0.152166
# OnlineBackup       -0.003351 -0.012057      -0.013632  0.153130    0.091015
# ...

# %%
train=data.drop("Churn",axis=1)
test=data["Churn"]

# %%
from sklearn import model_selection

# %%
x_train,x_test,y_train,y_test=model_selection.train_test_split(train,test)

# %%
data.to_csv("Churn_1.csv")

# %% [markdown]
# ### Data Visualization

# %%
plt.matshow(data.corr())
plt.show()

# %%
train.corrwith(test).plot.bar(figsize=(20,10),
                                           title="Correalation with response variable",
                                           fontsize=15,rot=45,grid=True)

# %%
train.drop(["gender","PhoneService","customerID","MultipleLines","InternetService","StreamingTV","StreamingMovies","TotalCharges"],axis=1,inplace=True)

# %%
sns.pairplot(data,hue="gender")
# Out:
# C:\Users\Harsh Bansal\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Harsh Bansal\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Harsh Bansal\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Harsh Bansal\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
# ...

# %%
#Plotting against most dependable features

# %%
plt.plot(data["Contract"],data["Churn"])
plt.xlabel("Contract")
plt.ylabel("Churn")
plt.show()

# %%
plt.scatter(data["tenure"],data["Churn"])
plt.xlabel("Tenure")
plt.ylabel("Churn")
plt.show()

# %%
plt.plot(data["MonthlyCharges"],data["Churn"])
plt.xlabel("Monthly Charges")
plt.ylabel("Churn")
plt.show()

# %%
plt.plot(data["Contract"],data["tenure"])
plt.xlabel("Contract")
plt.ylabel("Tenure")
plt.show()

# %%
sns.distplot(data["MonthlyCharges"])

# %%
sns.jointplot(x="MonthlyCharges",y="Churn",data=data)

# %%
sns.barplot(x="Contract",y="Churn",data=data)

# %%
### Conclusion: What all did you understand from the above charts
#The dependent variable Churn most depend on :
#1.Contract
#2.Tenure
#3.Monthly Charges
#4.Paperless Bill
#5.Online Security
#6.Tech Support

# %% [markdown]
# ### Implement Machine Learning Models

# %%
#On implying various machine learning best accuracy was achieved on Artifical Neural Network

# %%
#The model was build in R language as keras was not working on this ide because of some technical problem which can be solved

# %%
#R code:
''''data=read.csv("Churn_1.csv")
data$customerID=NULL
library(caTools)
split=sample.split(data$Churn,SplitRatio = 0.75)
train=subset(data,split==T)
test=subset(data,split==F)
train[,c(6,19,20)]=scale(train[,c(6,19,20)])
test[,c(6,19,20)]=scale(test[,c(6,19,20)])
library(h2o)
install.packages("h2o")
library(h2o)
h2o.init(nthreads = -1)
clf=h2o.deeplearning(y="Churn",training_frame = as.h2o(train),activation = "Rectifier",
                     hidden=c(8,8),epochs = 100,train_samples_per_iteration = -2)
prob_pred=h2o.predict(clf,newdata = as.h2o(test[-21]))
y_pred=(prob_pred>0.5)
y_pred=as.vector(y_pred)
cm=table(test[,21],y_pred)
cm
acc=(cm[1,1]+cm[2,2])/(cm[1,1]+cm[2,2]+cm[1,2]+cm[2,1])
acc
write.csv(y_pred,"Churn_pred.csv")
''''

# %%
#Accuracy was 0.8012324 last checked

# %%
#So we get accuracy of almost 80% means our output is 80% correct

# %% [markdown]
# ### Model Evaluation

# %%
#Confusion Matrix is used for evaluation

# %%
#It is also in R ide

# %%
#Confusion Matrix
 #    0    1
 # 0 1175  119
 # 1  269  198

# %% [markdown]
# ### Final Conclusions

# %%
#By analysing:
# Best model => Artificial Neural Network
# Most Important Features : Contract, Tenure, Online Security, Monthly Charges for predicting Churn
